# %%
# Data Transformations without using external libraries
# Right Skewed Distribution

import math

X = [10, 12, 13, 14, 15, 18, 40]
n = len(X)

# Min-Max
min_x = min(X)
max_x = max(X)
minmax = [(x - min_x) / (max_x - min_x) for x in X]

# Z-Score
mean = sum(X) / n
variance = sum((x - mean) ** 2 for x in X) / n
std_dev = math.sqrt(variance)
zscore = [(x - mean) / std_dev for x in X]

# Robust Scaling
sorted_X = sorted(X)
median = sorted_X[n // 2]
Q1 = sorted_X[n // 4]
Q3 = sorted_X[(3 * n) // 4]
IQR = Q3 - Q1
robust = [(x - median) / IQR for x in X]

# Log
log_trans = [math.log(x) for x in X]

# Square Root
sqrt_trans = [math.sqrt(x) for x in X]


# Neat Print Function
def show(title, data):
    print(f"{title:<25}: {[round(i, 4) for i in data]}")


# Output
print("\n" + "="*55)
print("     RIGHT SKEWED DISTRIBUTION – DATA TRANSFORMATIONS")
print("="*55)

show("Min-Max Normalization", minmax)
show("Z-Score Normalization", zscore)
show("Robust Scaling", robust)
show("Log Transformation", log_trans)
show("Square Root Transform", sqrt_trans)

print("="*55)
# Out:
# =======================================================
#      RIGHT SKEWED DISTRIBUTION – DATA TRANSFORMATIONS
# =======================================================
# Min-Max Normalization    : [0.0, 0.0667, 0.1, 0.1333, 0.1667, 0.2667, 1.0]
# Z-Score Normalization    : [-0.782, -0.5714, -0.4662, -0.3609, -0.2556, 0.0602, 2.376]
# Robust Scaling           : [-0.6667, -0.3333, -0.1667, 0.0, 0.1667, 0.6667, 4.3333]
# Log Transformation       : [2.3026, 2.4849, 2.5649, 2.6391, 2.7081, 2.8904, 3.6889]
# Square Root Transform    : [3.1623, 3.4641, 3.6056, 3.7417, 3.873, 4.2426, 6.3246]
# =======================================================
